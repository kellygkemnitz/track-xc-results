# %%
import dash
from dash import dash_table
from dash import dcc
from dash import html
from dash.dependencies import Input, Output
import json
import plotly.graph_objects as go
import pandas as pd

# %%
cross_country_data = 'data/xc-results.json'

# %%
df = pd.read_json(cross_country_data)

# %%
df
# Out:
#         Grade       Date                                       Meet Event  \
# 0   Sophomore 2022-09-10    Emporia Cross Country Invitational (JV)    5K
# 1   Sophomore 2022-09-24      Rim Rock Farm High School Classic (V)    5K
# 2   Sophomore 2022-10-01             Bishop Carrol Invitational (V)    5K
# 3   Sophomore 2022-10-15                           AVCTL League (V)    5K
# 4   Sophomore 2022-10-22                    KSHSAA 5A Regionals (V)    5K
# 5      Junior 2023-08-31                Great Bend Invitational (V)    5K
# 6      Junior 2023-09-09                   Emporia Invitational (V)    5K
# 7      Junior 2023-09-22                       Rim Rock Classic (V)    5K
# 8      Junior 2023-10-13                  AVCTL League - Salina (V)    5K
# 9      Junior 2023-10-21              Regionals - Bishop Carrol (V)    5K
# 10     Junior 2023-11-12                     NXR Heartland Regional    5K
# 11     Senior 2024-10-05  The Rush at Brown Thrush Invitational (V)    5K
# 12     Senior 2024-10-12                  Wild Wind XC Festival (V)    5K
# 13     Senior 2024-10-19                          AVCTL League (JV)    5K
# 14     Senior 2024-10-26           KSHSAA 6A Regionals - Hutchinson    5K
# 15     Senior 2024-11-02                 KSHSAA 6A State - Rim Rock    5K
#
#    Individual Place     Time Team Place
# 0              35th  24:19.4        NaN
# 1             133rd  23:08.8        NaN
# 2              38th  22:20.0        NaN
# 3              27th  21:47.4        NaN
# 4              30th  22:15.2        NaN
# 5              40th  23:08.7        4th
# 6              73rd  23:48.4        4th
# 7             129th  23:36.0        4th
# 8              25th  22:53.6        5th
# 9              30th  22:49.0        5th
# 10            143rd  22:05.1        5th
# 11             44th  22:35.8        8th
# 12             52nd  22:48.0        NaN
# 13              1st  21:08.6        NaN
# 14              8th  21:34.9        3rd
# 15             67th  21:25.8        3rd

# %%
df['Class']
# Out:
# 0    Sophomore
# 1       Junior
# 2       Senior
# Name: Class, dtype: object

# %%
df['Results']
# Out:
# 0    [{'Date': '2022-09-10', 'Meet': 'Emporia Cross...
# 1    [{'Date': '2023-08-31', 'Meet': 'Great Bend In...
# 2    [{'Date': '2024-10-05', 'Meet': 'The Rush at B...
# Name: Results, dtype: object
